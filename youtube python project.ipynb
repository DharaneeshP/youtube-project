# %%
import pandas as pd
import googleapiclient.discovery
import sqlite3
import pymongo
import json
import streamlit as st


api_key='AIzaSyD_nvYwsEZzHGzcTHck3OVs46D0SM439SA'
channel_ids=['UCnKhQkCUS1oCEvjuTfU4xIw',
            'UC6NK95qassTilrIVwD5oA7Q',
            'UCVpsy4loLHxlo-JU8w1usLw', 
            'UCwV65zx2c8rCL8NhARci1Hw',
            'UCXRoShpgQqFC1cJNs9kWMlA',  
            'UCNFa9HtV-xYSRuTazrJhIFA',   
            'UC_6QwiVNDqtaTSTxhQPe_6Q',  
            'UCUdqzTNRbjZhHbkfojI2RaA',
            'UCJgh66s0lUVkL19Fzenf8vw',
            'UCr94q5r1qUrwg2Z6IJB3tuw'
            ]

# %%
youtube = googleapiclient.discovery.build("youtube", "v3", developerKey=api_key)

# %%
 #getting yt channel details   
def get_channel_info(channel_ids):
        
        request = youtube.channels().list(

            part="snippet,contentDetails,statistics",
            id=channel_ids)

        response = request.execute()

        for i in range(len(response["items"])):
            data = dict(Channel_Id=response['items'][i]["id"],
                        Channel_Name=response['items'][i]['snippet']["title"],
                        Subscription_Count=response['items'][i]['statistics']['subscriberCount'],
                        Channel_Views=response['items'][i]['statistics']["viewCount"],
                        Total_videos=response['items'][i]['statistics']['videoCount'],
                        Playlist_Id=response['items'][i]['contentDetails']['relatedPlaylists']['uploads'],
                        Channel_Description=response['items'][i]["snippet"]['description'],
                        Published_At=response['items'][i]["snippet"]['publishedAt']
                        )

        return data

# %%
get_channel_info(channel_ids)
# Out:
# {'Channel_Id': 'UCwV65zx2c8rCL8NhARci1Hw',
#  'Channel_Name': 'Trending Theeviravadhi',
#  'Subscription_Count': '4800000',
#  'Channel_Views': '1400890609',
#  'Total_videos': '342',
#  'Playlist_Id': 'UUwV65zx2c8rCL8NhARci1Hw',
#  'Channel_Description': 'Trending thivaravadhi Official\n',
#  'Published_At': '2020-11-05T17:28:38.661491Z'}

# %%
first_table=get_channel_info(channel_ids)

# %%
first_table
# Out:
# {'Channel_Id': 'UCJgh66s0lUVkL19Fzenf8vw',
#  'Channel_Name': 'விவசாயம் காப்போம்',
#  'Subscription_Count': '572000',
#  'Channel_Views': '64075885',
#  'Total_videos': '1278',
#  'Playlist_Id': 'UUJgh66s0lUVkL19Fzenf8vw',
#  'Channel_Description': "For  Sponsors and enquiries contact me on Below \nemail: \nvivasayamkaapom2.0@gmail.com\nவிவசாய நண்பர்கள் அனைவருக்கும் வணக்கம்\n\n இந்த  ' விவசாயம் காப்போம்' youtube channel  ஆனது முற்றிலும் விவசாயிகளுக்கானது இந்த சேனலில்  \n               * கோழி வளர்ப்பு, \n               * ஆடு வளர்ப்பு,\n               *மாடு வளர்ப்பு,\n               *மீன் வளர்ப்பு,\n               *அசோலா வளர்ப்பு,\n               *காளான் வளர்ப்பு,  \nஅனைத்து கால்நடைகள் மற்றும் விவசாயம் சார்ந்த தகவல்கள் பதிவு செய்யப்படும்.\n  \n                     கண்களுக்கு தெரிந்த கடவுள் 'விவசாயி'\n\n                        **வாழ்க விவசாயி!  வளர்க விவசாயம்!**",
#  'Published_At': '2018-04-16T17:27:15Z'}

# %%
 # getting playlist ids
def get_playlist_info(channel_ids):
        request = youtube.channels().list(
            part="contentDetails",
            id=channel_ids
        )
        response = request.execute()
        uploads_playlist_id = response['items'][0]['contentDetails']['relatedPlaylists']['uploads']
        return uploads_playlist_id

# %%
 get_playlist_info(channel_ids)
# Out:
# 'UU6NK95qassTilrIVwD5oA7Q'

# %%
playlist_id= get_playlist_info(channel_ids)

# %%
#getting all video ids
def get_videos_ids( youtube, playlist_id):
    

        video_ids = []

        request = youtube.playlistItems().list(
            part="contentDetails",
            playlistId=playlist_id,
            maxResults=50)

        response = request.execute()

        for i in range(len(response['items'])):
            video_ids.append(response['items'][i]['contentDetails']['videoId'])

        next_page_token = response.get('nextPageToken')
        more_pages = True

        while more_pages:

            if next_page_token is None:
                more_pages = False
            else:
                request = youtube.playlistItems().list(
                    part="contentDetails",
                    playlistId=playlist_id,
                    maxResults=50,
                    pageToken=next_page_token)

                response = request.execute()
                for i in range(len(response['items'])):
                    video_ids.append(response['items'][i]['contentDetails']['videoId'])

                next_page_token = response.get('nextPageToken')

        return video_ids

# %%
 video_ids= get_videos_ids( youtube, playlist_id)

# %%
video_ids
# Out:
# ['POzKV0CYRL0',
#  'MWnXJ9KGH7I',
#  '22IJ0uoo8i4',
#  'WPOc5oVqTVM',
#  '8QOtNN-CwNw',
#  'JU8_OISkW4o',
#  '9JTnhLIn37Y',
#  'nlGZeqx8V5U',
#  '_QWetmlAK4g',
#  '6SNSWY9avKI',
#  'xtR9vBJ7sBE',
#  'QkW4Kb6LSbU',
#  'jUcVGB3TC_w',
#  'ILAxbsvGEVk',
#  '56VqNSFZskc',
#  'UwJVa-bBVwA',
#  'XqwLuUVo_94',
#  '-IcHamZOdeY',
#  'jLZKbgJ_wKk',
#  '0Zy1CMqyCPo',
#  'NLizjSvbbx8',
#  'zgrB2gTdfgM',
#  '3EWs1f1gHnc',
#  '0k7mll139yw',
#  'MIZCLEjKI28',
#  '44nJiEgXFHc',
#  'MRTRTixb9CY',
#  'LzSvN4TKa1A',
#  '0SxpEqvUWZ4',
#  'flhheH81uDo',
#  'F-GoIJBvH_8',
#  'A8Mhv0neAi4',
#  'OMJ8TgtNbA8',
#  'uo7LkPzrupg',
#  'dgT1ZAOpXXw',
#  '7LtYGD9p7NA',
#  '_yBCO8BN7gk',
#  '7fZrEZVs_qw',
#  'DWKxP2CHkcI',
#  '0YSOKTZ1pLY',
#  'iP-BLC2AwIg',
#  'pu43_kYtq_w',
#  'BdRLB5HIMw0',
#  'L-TRMjA8zzg',
#  'xqE4qEO9F6I',
#  'vh9YYLKik0Y',
#  'E16u38M-Kfo',
#  'tQJlLzOJPIY',
#  'mc_kioNeqMs',
#  '1WnoVGTPzNw',
#  '4dD4PeIQgpQ',
#  'HNZf4tpAWOU',
#  'JfPt7IQFQs0',
#  'vqquQPcvJ6o',
#  'z089YP-7CjQ',
# ...

# %%
# getting all video details
def get_video_details(video_ids):
    
        all_video_stats = []

        for i in range(0, len(video_ids), 50):
            request = youtube.videos().list(
                part='snippet,contentDetails,statistics',
                id=','.join(video_ids[i:i + 50])
            )
            response = request.execute()

            for video in response['items']:
                video_stats = dict(
                    Title=video['snippet']['title'],
                    Published_date=video['snippet']['publishedAt'],
                    Views=video['statistics']['viewCount'],
                    Duration=video['contentDetails']['duration'],
                )

                all_video_stats.append(video_stats)

        return all_video_stats

# %%
get_video_details(video_ids)
# Out:
# [{'Title': 'Participate in #KaruKaruKarupayi only on YouTube Shorts. #TrendingOnShorts #Shorts',
#   'Published_date': '2023-11-09T07:31:03Z',
#   'Views': '278388',
#   'Duration': 'PT32S'},
#  {'Title': 'Girlfriend Koolaaru 😂 Description link✨Wow dress shop Chennai navalur💥#dress #diwali',
#   'Published_date': '2023-11-02T15:01:42Z',
#   'Views': '1696367',
#   'Duration': 'PT1M'},
#  {'Title': 'Aayudha poojai💥 EMI paavam🤣 Goutham | #trendingtheeviravadhi #comedy #leo',
#   'Published_date': '2023-10-22T12:10:46Z',
#   'Views': '5821003',
#   'Duration': 'PT1M'},
#  {'Title': 'DIWALI SPECIAL🔥Damaal dumeel💥🔥❤️Really Semmaya irukku crackers Kandippa Vaangunga👍',
#   'Published_date': '2023-10-21T15:39:33Z',
#   'Views': '3643106',
#   'Duration': 'PT1M'},
#  {'Title': 'Thanks for the award 🌟❤️ TRENDING FACE FOR THE DIGITAL | #trendingtheeviravadhi',
#   'Published_date': '2023-10-15T10:14:59Z',
#   'Views': '241747',
#   'Duration': 'PT1M1S'},
# ...

# %%
second_table=get_video_details(video_ids)

# %%
second_table
# Out:
# [{'Title': 'Participate in #KaruKaruKarupayi only on YouTube Shorts. #TrendingOnShorts #Shorts',
#   'Published_date': '2023-11-09T07:31:03Z',
#   'Views': '278388',
#   'Duration': 'PT32S'},
#  {'Title': 'Girlfriend Koolaaru 😂 Description link✨Wow dress shop Chennai navalur💥#dress #diwali',
#   'Published_date': '2023-11-02T15:01:42Z',
#   'Views': '1696367',
#   'Duration': 'PT1M'},
#  {'Title': 'Aayudha poojai💥 EMI paavam🤣 Goutham | #trendingtheeviravadhi #comedy #leo',
#   'Published_date': '2023-10-22T12:10:46Z',
#   'Views': '5821003',
#   'Duration': 'PT1M'},
#  {'Title': 'DIWALI SPECIAL🔥Damaal dumeel💥🔥❤️Really Semmaya irukku crackers Kandippa Vaangunga👍',
#   'Published_date': '2023-10-21T15:39:33Z',
#   'Views': '3643106',
#   'Duration': 'PT1M'},
#  {'Title': 'Thanks for the award 🌟❤️ TRENDING FACE FOR THE DIGITAL | #trendingtheeviravadhi',
#   'Published_date': '2023-10-15T10:14:59Z',
#   'Views': '241747',
#   'Duration': 'PT1M1S'},
# ...

# %%
  #  Getting All commment details
def get_comment_threads(video_ids):
        all_comments = []

        for video_id in video_ids:
            
            try:
                request = youtube.commentThreads().list(
                    part="snippet,replies",
                    videoId=video_id,
                    maxResults=50
                )

                response = request.execute()
                for i in response['items']:
                    comments_in_video = dict(Comment_Id=i["id"],
                                             Comment_Author=i["snippet"]["topLevelComment"]["snippet"]["authorDisplayName"],
                                             Comment_Text=i["snippet"]["topLevelComment"]["snippet"]["textDisplay"],
                                             Comment_PublishedAt=i["snippet"]["topLevelComment"]["snippet"]["publishedAt"],
                                             Video_Id=i["snippet"]["topLevelComment"]["snippet"]["videoId"])

                    all_comments.append(comments_in_video)
                    comments = {"comments": all_com}


            except:
                comments = {"comments": None}

                
            
            
            
        return all_comments

# %%
 get_comment_threads(video_ids)
# Out:
# [{'Comment_Id': 'UgyoyegL2DPIlCLxOcN4AaABAg',
#   'Comment_Author': 'P. Jeeva P. Jeeva',
#   'Comment_Text': 'Super bro😎',
#   'Comment_PublishedAt': '2023-11-10T04:34:01Z',
#   'Video_Id': 'POzKV0CYRL0'},
#  {'Comment_Id': 'UgyNAM6jyQw1AnLzXwd4AaABAg',
#   'Comment_Author': 'Vin Aravinthan',
#   'Comment_Text': 'original song name',
#   'Comment_PublishedAt': '2023-11-09T16:40:11Z',
#   'Video_Id': '22IJ0uoo8i4'},
#  {'Comment_Id': 'UgzPV2t64Hqtfw9pV_x4AaABAg',
#   'Comment_Author': 'R V R Channel',
#   'Comment_Text': 'Super',
#   'Comment_PublishedAt': '2023-11-10T03:39:27Z',
#   'Video_Id': 'WPOc5oVqTVM'},
#  {'Comment_Id': 'Ugwz-F8K_se9Ya9lC8p4AaABAg',
#   'Comment_Author': 'Thazna moorthy Thazna moorty',
#   'Comment_Text': 'Congratulations bro ❤',
#   'Comment_PublishedAt': '2023-11-09T16:24:12Z',
#   'Video_Id': '8QOtNN-CwNw'},
#  {'Comment_Id': 'UgxNMH5KBlj44a1_poJ4AaABAg',
#   'Comment_Author': 'jagada sumithra',
# ...

# %%
third_table= get_comment_threads(video_ids)

# %%
 #  Merging All Deatils Of Given Channel Together
def get_all_youtube_data(api_key, channel_ids):
        channel_info = get_channel_info(channel_ids) 
        playlist_info = get_playlist_info(channel_ids) 
        video_information = get_video_details(video_ids)
        tot_comments = get_comment_threads(video_ids)

        data = {
                "Channel_details": channel_info,
                "Playlist_details": playlist_info,
                "Video_details": video_information,
                "Comment_details": tot_comments
               }

        return data

# %%
 get_all_youtube_data(api_key, channel_ids)
# Out:
# {'Channel_details': {'Channel_Id': 'UCJgh66s0lUVkL19Fzenf8vw',
#   'Channel_Name': 'விவசாயம் காப்போம்',
#   'Subscription_Count': '572000',
#   'Channel_Views': '64075885',
#   'Total_videos': '1278',
#   'Playlist_Id': 'UUJgh66s0lUVkL19Fzenf8vw',
#   'Channel_Description': "For  Sponsors and enquiries contact me on Below \nemail: \nvivasayamkaapom2.0@gmail.com\nவிவசாய நண்பர்கள் அனைவருக்கும் வணக்கம்\n\n இந்த  ' விவசாயம் காப்போம்' youtube channel  ஆனது முற்றிலும் விவசாயிகளுக்கானது இந்த சேனலில்  \n               * கோழி வளர்ப்பு, \n               * ஆடு வளர்ப்பு,\n               *மாடு வளர்ப்பு,\n               *மீன் வளர்ப்பு,\n               *அசோலா வளர்ப்பு,\n               *காளான் வளர்ப்பு,  \nஅனைத்து கால்நடைகள் மற்றும் விவசாயம் சார்ந்த தகவல்கள் பதிவு செய்யப்படும்.\n  \n                     கண்களுக்கு தெரிந்த கடவுள் 'விவசாயி'\n\n                        **வாழ்க விவசாயி!  வளர்க விவசாயம்!**",
#   'Published_At': '2018-04-16T17:27:15Z'},
#  'Playlist_details': 'UUJgh66s0lUVkL19Fzenf8vw',
# ...

# %%
a= get_all_youtube_data(api_key, channel_ids)

# %%
a
# Out:
# {'Channel_details': {'Channel_Id': 'UCUdqzTNRbjZhHbkfojI2RaA',
#   'Channel_Name': 'Pachonthi official ',
#   'Subscription_Count': '1120000',
#   'Channel_Views': '406907565',
#   'Total_videos': '571',
#   'Playlist_Id': 'UUUdqzTNRbjZhHbkfojI2RaA',
#   'Channel_Description': 'WELCOME FOODIE\n\n#shorts #pachonthiofficial #foodchallenges\n',
#   'Published_At': '2020-10-12T06:45:19.26235Z'},
#  'Playlist_details': 'UUUdqzTNRbjZhHbkfojI2RaA',
#  'Video_details': [{'Title': 'Thirutu paiyen da neenu⁉️🤯 #shorts #comedy #pachonthi',
#    'Published_date': '2023-10-20T12:30:30Z',
#    'Views': '77439',
#    'Duration': 'PT59S'},
#   {'Title': 'Ithu rommba rommba tuf challenge🤯😢 #shorts #pachonthi  #comedy',
#    'Published_date': '2023-10-19T12:30:53Z',
#    'Views': '171767',
#    'Duration': 'PT41S'},
#   {'Title': 'Police kitta Ena da pandra🤯😢 #shorts #pachonthiofficial  #comedy',
#    'Published_date': '2023-10-18T12:30:11Z',
#    'Views': '218138',
#    'Duration': 'PT44S'},
# ...

# %%
# python mongo connectivity

# %%
from pymongo import MongoClient

# %%
client = pymongo.MongoClient("mongodb://localhost:27017/") 
db = client["youtube"]   
collection = db["data"]

# %%
insert_data=collection.insert_one(a)

# %%
insert_data

# %%
# sql python connectivity

# %%
conn= sqlite3.connect('students.db')

# %%
c=conn.cursor()

# %%
first_table
# Out:
# {'Channel_Id': 'UCJgh66s0lUVkL19Fzenf8vw',
#  'Channel_Name': 'விவசாயம் காப்போம்',
#  'Subscription_Count': '572000',
#  'Channel_Views': '64063255',
#  'Total_videos': '1278',
#  'Playlist_Id': 'UUJgh66s0lUVkL19Fzenf8vw',
#  'Channel_Description': "For  Sponsors and enquiries contact me on Below \nemail: \nvivasayamkaapom2.0@gmail.com\nவிவசாய நண்பர்கள் அனைவருக்கும் வணக்கம்\n\n இந்த  ' விவசாயம் காப்போம்' youtube channel  ஆனது முற்றிலும் விவசாயிகளுக்கானது இந்த சேனலில்  \n               * கோழி வளர்ப்பு, \n               * ஆடு வளர்ப்பு,\n               *மாடு வளர்ப்பு,\n               *மீன் வளர்ப்பு,\n               *அசோலா வளர்ப்பு,\n               *காளான் வளர்ப்பு,  \nஅனைத்து கால்நடைகள் மற்றும் விவசாயம் சார்ந்த தகவல்கள் பதிவு செய்யப்படும்.\n  \n                     கண்களுக்கு தெரிந்த கடவுள் 'விவசாயி'\n\n                        **வாழ்க விவசாயி!  வளர்க விவசாயம்!**",
#  'Published_At': '2018-04-16T17:27:15Z'}

# %%
table_name = "Channel_details"
create_table_sql = f'''
    CREATE TABLE IF NOT EXISTS "{table_name}" (
        id INTEGER PRIMARY KEY AUTOINCREMENT,
        json_data TEXT
    );
'''

# %%
c.execute(create_table_sql)
json_data = str(first_table)  # Convert the dictionary to a JSON-formatted string
c.execute(f'INSERT INTO {table_name} (json_data) VALUES (?)', (json_data,))

conn.commit()

# %%
tablee_name = "video_details"
create_tablee_sql = f'''
    CREATE TABLE IF NOT EXISTS "{tablee_name}" (
        id INTEGER PRIMARY KEY AUTOINCREMENT,
        json_data TEXT
    );
'''

c.execute(create_tablee_sql)
second_json_data = str(second_table)  
c.execute(f'INSERT INTO {tablee_name} (json_data) VALUES (?)', (second_json_data,))

conn.commit()

# %%
tableee_name = "comment_details"
create_tableee_sql = f'''
    CREATE TABLE IF NOT EXISTS "{tableee_name}" (
        id INTEGER PRIMARY KEY AUTOINCREMENT,
        json_data TEXT
    );
'''

c.execute(create_tableee_sql)
third_json_data = str(third_table)
c.execute(f'INSERT INTO {tableee_name} (json_data) VALUES (?)', (third_json_data,))

conn.commit()

# %%
c.close()
conn.close()
